# %% [markdown]
# <a href="https://colab.research.google.com/github/jazacmq/Lampornis/blob/main/Lamp_ejemplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tener acceso a drive
from google.colab import drive
drive.mount('/content/drive')

# %%
#de la carpeta de lampornis de my drive descargar los 2 csv
import pandas as pd
gdp = pd.read_csv('/content/drive/MyDrive/Lampornis/gdp_per_capita.csv', sep='\t', encoding='latin1', thousands=',', na_values='n/a').dropna()
gdp.head()
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#         2015  Estimates Start After
# 0    599.994                 2013.0
# ...

# %%
oecd = pd.read_csv('/content/drive/MyDrive/Lampornis/oecd.csv', thousands=',')[['Country', 'Indicator', 'Measure', 'Inequality', 'Unit', 'PowerCode', 'Value']]
oecd.head()
# Out:
#           Country                 Indicator Measure Inequality        Unit  \
# 0       Australia  Labour market insecurity   Value      Total  Percentage
# 1         Austria  Labour market insecurity   Value      Total  Percentage
# 2         Belgium  Labour market insecurity   Value      Total  Percentage
# 3          Canada  Labour market insecurity   Value      Total  Percentage
# 4  Czech Republic  Labour market insecurity   Value      Total  Percentage
#
#   PowerCode  Value
# 0     Units    5.4
# 1     Units    3.5
# 2     Units    3.7
# 3     Units    6.0
# 4     Units    3.1

# %%
print(gdp.columns)
gdp.shape
# Out:
# Index(['Country', 'Subject Descriptor', 'Units', 'Scale',
#        'Country/Series-specific Notes', '2015', 'Estimates Start After'],
#       dtype='object')
# (187, 7)

# %%
print(gdp['Units'].unique())
print(gdp['Subject Descriptor'].unique())
print(gdp['Estimates Start After'].unique())
print(gdp['Estimates Start After'].unique())
estimados=gdp
# Out:
# ['U.S. dollars']
# ['Gross domestic product per capita, current prices']
# [2013. 2010. 2014. 2011. 2015. 2012. 2008.    0. 2004. 2003. 1983. 2009.
#  2007. 2006. 2002. 2001.]
# [2013. 2010. 2014. 2011. 2015. 2012. 2008.    0. 2004. 2003. 1983. 2009.
#  2007. 2006. 2002. 2001.]

# %%
gdp.info()
oecd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        187 non-null    object
#  1   Subject Descriptor             187 non-null    object
#  2   Units                          187 non-null    object
#  3   Scale                          187 non-null    object
#  4   Country/Series-specific Notes  187 non-null    object
#  5   2015                           187 non-null    float64
#  6   Estimates Start After          187 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 11.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2368 entries, 0 to 2367
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     2368 non-null   object
#  1   Indicator   2368 non-null   object
# ...

# %%
pais_satisfaccion = oecd[['Country', 'Value']][oecd['Indicator'] == 'Life satisfaction']
oecd.head(10)
# Out:
#           Country                 Indicator Measure Inequality        Unit  \
# 0       Australia  Labour market insecurity   Value      Total  Percentage
# 1         Austria  Labour market insecurity   Value      Total  Percentage
# 2         Belgium  Labour market insecurity   Value      Total  Percentage
# 3          Canada  Labour market insecurity   Value      Total  Percentage
# 4  Czech Republic  Labour market insecurity   Value      Total  Percentage
# 5         Denmark  Labour market insecurity   Value      Total  Percentage
# 6         Finland  Labour market insecurity   Value      Total  Percentage
# 7          France  Labour market insecurity   Value      Total  Percentage
# 8         Germany  Labour market insecurity   Value      Total  Percentage
# 9          Greece  Labour market insecurity   Value      Total  Percentage
#
#   PowerCode  Value
# 0     Units    5.4
# 1     Units    3.5
# 2     Units    3.7
# 3     Units    6.0
# 4     Units    3.1
# 5     Units    4.2
# ...

# %%
print(len(oecd['Country'].unique()))
print(len(gdp['Country'].unique()))
print(oecd.shape)
print(gdp.shape)
pais_indicador_labor=oecd[['Country','Indicator','Value']][oecd['Indicator']=='Labour market insecurity']
pais_indicador_labor.head()
pais_indicador_labor.tail()
print(pais_indicador_labor['Value'].max())
print(pais_indicador_labor['Value'].min())
print(pais_indicador_labor[['Country']][pais_indicador_labor['Value']==pais_indicador_labor['Value'].max()])
print(pais_indicador_labor[['Country']][pais_indicador_labor['Value']==pais_indicador_labor['Value'].min()])
pais_indicador_labor.sort_values(by='Value',ascending=False)
# Out:
# 41
# 187
# (2368, 7)
# (187, 7)
# 72.16
# 0.3
#              Country
# 151  Slovak Republic
#    Country
# 80   Japan
#              Country                 Indicator  Value
# 151  Slovak Republic  Labour market insecurity  72.16
# 152            Spain  Labour market insecurity  36.71
# 75            Greece  Labour market insecurity  36.00
# 139           Greece  Labour market insecurity  32.72
# 9             Greece  Labour market insecurity  29.80
# ..               ...                       ...    ...
# 45           Iceland  Labour market insecurity   0.70
# 77           Iceland  Labour market insecurity   0.70
# 141          Iceland  Labour market insecurity   0.62
# 109          Iceland  Labour market insecurity   0.59
# 80             Japan  Labour market insecurity   0.30
#
# [162 rows x 3 columns]

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# Muestra las primeras 10 filas del dataset GDP

# %%
gdp.head(10)
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
# 5            Argentina  Gross domestic product per capita, current prices
# 6              Armenia  Gross domestic product per capita, current prices
# 7            Australia  Gross domestic product per capita, current prices
# 8              Austria  Gross domestic product per capita, current prices
# 9           Azerbaijan  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# ...

# %% [markdown]
# Obtén el número de filas y columnas de cada dataset

# %%
print(gdp.shape)
oecd.shape
# Out:
# (187, 7)
# (2368, 7)

# %% [markdown]
# Muestra estadísticas de las columnas numéricas del dataset GDP

# %%
gdp.describe()
# Out:
#                 2015
# count     187.000000
# mean    12591.099604
# std     17386.345358
# min       220.860000
# 25%      1783.538000
# 50%      5373.633000
# 75%     15490.576500
# max    101994.093000

# %% [markdown]
# Selecciona solo las columnas 'Country' y '2015' del dataset GDP

# %%
gdp=gdp[['Country','2015']]
gdp.head()
# Out:
#                Country       2015
# 0          Afghanistan    599.994
# 1              Albania   3995.383
# 2              Algeria   4318.135
# 3               Angola   4100.315
# 4  Antigua and Barbuda  14414.302

# %% [markdown]
# Filtra los países del dataset GDP donde el valor de 2015 sea mayor a 5000

# %%
gdp[gdp['2015']>5000]
# Out:
#                   Country       2015
# 4     Antigua and Barbuda  14414.302
# 5               Argentina  13588.846
# 7               Australia  50961.865
# 8                 Austria  43724.031
# 9              Azerbaijan   5739.433
# ..                    ...        ...
# 178  United Arab Emirates  36060.015
# 179        United Kingdom  43770.688
# 180         United States  55805.204
# 181               Uruguay  15748.192
# 184             Venezuela   7744.746
#
# [95 rows x 2 columns]

# %% [markdown]
# Renombra la columna '2015' a 'GDP_2015' en el dataset GDP

# %%
gdp=gdp.rename(columns={'2015':'GDP_2015'})
gdp.head()
# Out:
#                Country   GDP_2015
# 0          Afghanistan    599.994
# 1              Albania   3995.383
# 2              Algeria   4318.135
# 3               Angola   4100.315
# 4  Antigua and Barbuda  14414.302

# %% [markdown]
# Filtra el dataset OECD para mostrar solo los datos donde 'Indicator'
# sea 'Life satisfaction' y 'Value' sea mayor a 6.5

# %%
oecd[oecd['Indicator'].isin(['Life satisfaction'])].query('Value > 6.5')
# Out:
#              Country          Indicator Measure Inequality           Unit  \
# 1812       Australia  Life satisfaction   Value      Total  Average score
# 1813         Austria  Life satisfaction   Value      Total  Average score
# 1814         Belgium  Life satisfaction   Value      Total  Average score
# 1815          Canada  Life satisfaction   Value      Total  Average score
# 1816  Czech Republic  Life satisfaction   Value      Total  Average score
# ...              ...                ...     ...        ...            ...
# 1955    OECD - Total  Life satisfaction   Value       High  Average score
# 1956         Finland  Life satisfaction   Value        Low  Average score
# 1960         Iceland  Life satisfaction   Value        Low  Average score
# 1962          Norway  Life satisfaction   Value        Low  Average score
# 1966  United Kingdom  Life satisfaction   Value        Low  Average score
#
#      PowerCode  Value
# 1812     Units    7.3
# 1813     Units    7.1
# ...

# %% [markdown]
# Agrupa el dataset OECD por 'Country' y calcula el promedio de 'Value' para cada país

# %%
oecd.groupby('Country').agg({'Value' : 'mean'})
# Out:
#                         Value
# Country
# Australia         8699.055932
# Austria           6402.024677
# Belgium           7592.570323
# Brazil              87.413000
# Canada            8182.153387
# Chile             2298.454211
# Colombia            81.897273
# Czech Republic     901.992982
# Denmark           3298.681290
# Estonia           3253.385625
# Finland           4355.083594
# France            5631.751094
# Germany           5585.447419
# Greece            3305.270500
# Hungary           2226.742203
# Iceland           1146.682414
# Ireland           4997.669661
# Israel             789.495600
# Italy             5433.064531
# Japan             7324.015192
# Korea             6095.540526
# Latvia            1791.752500
# Lithuania          915.104182
# Luxembourg       15365.115088
# Mexico             349.284000
# Netherlands       4219.055517
# New Zealand       8024.062407
# Norway            5437.074915
# OECD - Total      7678.438281
# ...

# %% [markdown]
# Ordena el dataset GDP por la columna '2015' de forma descendente

# %%
gdp.sort_values('GDP_2015',axis=0,ascending=False)
# Out:
#                       Country    GDP_2015
# 98                 Luxembourg  101994.093
# 162               Switzerland   80675.308
# 135                     Qatar   76576.080
# 124                    Norway   74822.106
# 180             United States   55805.204
# ..                        ...         ...
# 100                Madagascar     401.771
# 101                    Malawi     354.275
# 31   Central African Republic     334.870
# 26                    Burundi     305.783
# 152               South Sudan     220.860
#
# [187 rows x 2 columns]

# %% [markdown]
# Elimina las columnas 'Scale' y 'Country/Series-specific Notes' del dataset GDP

# %%
gdp.head()
# Out:
#                Country   GDP_2015
# 0          Afghanistan    599.994
# 1              Albania   3995.383
# 2              Algeria   4318.135
# 3               Angola   4100.315
# 4  Antigua and Barbuda  14414.302

# %% [markdown]
# Encuentra todos los valores únicos de la columna 'Subject Descriptor' en el dataset GDP

# %% [markdown]
# Cuenta cuántas veces aparece cada 'Indicator' en el dataset OECD

# %%
oecd['Indicator'].unique()
print(oecd['Indicator'].count())
len(oecd['Indicator'].unique())
oecd.value_counts('Indicator')
# Out:
# 2368
# Indicator
# Student skills                                       200
# Self-reported health                                 182
# Life satisfaction                                    168
# Quality of support network                           168
# Labour market insecurity                             162
# Feeling safe walking alone at night                  123
# Employment rate                                      123
# Homicide rate                                        123
# Life expectancy                                      123
# Water quality                                        123
# Educational attainment                               120
# Years in education                                   120
# Long-term unemployment rate                          117
# Employees working very long hours                    117
# Time devoted to leisure and personal care             69
# Air pollution                                         41
# ...

# %% [markdown]
# Combina ambos datasets usando 'Country' como llave, manteniendo solo los países presentes en ambos

# %%
print(gdp.head())
oecd.head()
# Out:
#                Country   GDP_2015
# 0          Afghanistan    599.994
# 1              Albania   3995.383
# 2              Algeria   4318.135
# 3               Angola   4100.315
# 4  Antigua and Barbuda  14414.302
#           Country                 Indicator Measure Inequality        Unit  \
# 0       Australia  Labour market insecurity   Value      Total  Percentage
# 1         Austria  Labour market insecurity   Value      Total  Percentage
# 2         Belgium  Labour market insecurity   Value      Total  Percentage
# 3          Canada  Labour market insecurity   Value      Total  Percentage
# 4  Czech Republic  Labour market insecurity   Value      Total  Percentage
#
#   PowerCode  Value
# 0     Units    5.4
# 1     Units    3.5
# 2     Units    3.7
# 3     Units    6.0
# 4     Units    3.1

# %% [markdown]
# Crea una tabla pivote con el dataset OECD que muestre el promedio de 'Value'
# por 'Country' e 'Indicator'

# %% [markdown]
#  Crea una nueva columna en el dataset GDP que categorice los valores de 2015 como 'Bajo', 'Medio' o 'Alto' según percentiles

# %% [markdown]
# Convierte la columna 'Estimates Start After' a formato datetime (año)

# %% [markdown]
# Después de hacer merge, calcula la correlación entre GDP 2015 y Life satisfaction

# %% [markdown]
#  Encuentra los 10 países con mayor GDP en 2015 y muestra su información de Life satisfaction

# %% [markdown]
# Para el dataset OECD, agrupa por 'Country' y calcula múltiples estadísticas para 'Value'

# %% [markdown]
#  Get countries + Life satisfaction

# %% [markdown]
# Get countries + GDP

# %% [markdown]
# Unir las tablas de PIB(GDP) y satisfacción con la vida + Agrupar por país como columna única y el PIB promedio agregado y la satisfacción con la vida
# Enviar comentarios
# Presiona Tab para ver las acciones
